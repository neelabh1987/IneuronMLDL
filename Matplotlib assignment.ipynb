# %% [markdown]
# ## Scipy:
# ### We have the min and max temperatures in a city In India for each months of the year.
# ### We would like to find a function to describe this and show it graphically, the dataset
# ### given below.
# ### Task:
# ### 1. fitting it to the periodic function
# ### 2. plot the fit
# ### Data
# ### Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# ### Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
max_temp = np.array ([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
min_temp = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

# %%
months = np.arange(12)
plt.plot(months,max_temp,'ro')
plt.plot(months,min_temp,'bo')
plt.xlabel('Month')
plt.ylabel('Min and Max Temperatures')
# Out:
# Text(0, 0.5, 'Min and Max Temperatures')

# %%
from scipy import optimize

def yearly_temp(times, avg , ampl , time_offset):
    return (avg + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temp, months,
                                      max_temp, [20, 10, 0])

res_min, cov_min = optimize.curve_fit(yearly_temp, months,
                                      min_temp, [-40, 20, 0])

# %%
days = np.linspace(0,12,num=365)
plt.figure(figsize = (9,9))
plt.plot(months,max_temp,'ro')
plt.plot(days,yearly_temp(days, *res_max), 'r-')
plt.plot(months, min_temp, 'bo')
plt.plot(days, yearly_temp(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %% [markdown]
# ## Matplotlib:
# ## This assignment is for visualization using matplotlib:
# ## data to use:
# ## url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
# ## titanic = pd.read_csv(url)
# ## Charts to plot:
# ## 1. Create a pie chart presenting the male/female proportion
# ## 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
url = 'https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
male = titanic[titanic['sex'] == 'male']['sex'].count()/len(titanic)*100
female = titanic[titanic['sex'] == 'female']['sex'].count()/len(titanic)*100

# %%
fig = plt.figure(figsize = (8,8))
plt.pie(data = titanic['sex'], x = [male, female], labels = ['male percentage', 'female percentage'], autopct='%1.1f%%')
plt.show()

# %%
m = titanic[titanic['sex'] == 'male']
f = titanic[titanic['sex'] == 'female']
plt.figure(figsize = (11,8))
plt.plot(m.fare, m.age, '.b', label = 'Male')
plt.plot(f.fare, f.age,'.r', label = 'Female')
plt.axis('equal')
plt.xlabel('Fare')
plt.ylabel('Age')
leg = plt.legend()
